# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import os

# %% [markdown]
# ## Load January Data

# %%
jan_df=pd.read_csv('SalesData/Sales_January_2019.csv')
jan_df
# Out:
#      Order ID                   Product Quantity Ordered Price Each  \
# 0      141234                    iPhone                1        700
# 1      141235  Lightning Charging Cable                1      14.95
# 2      141236          Wired Headphones                2      11.99
# 3      141237          27in FHD Monitor                1     149.99
# 4      141238          Wired Headphones                1      11.99
# ...       ...                       ...              ...        ...
# 9718   150497              20in Monitor                1     109.99
# 9719   150498          27in FHD Monitor                1     149.99
# 9720   150499           ThinkPad Laptop                1     999.99
# 9721   150500    AAA Batteries (4-pack)                2       2.99
# 9722   150501              Google Phone                1        600
#
#           Order Date                       Purchase Address
# 0     01/22/19 21:25        944 Walnut St, Boston, MA 02215
# ...

# %% [markdown]
# ## Load February Data

# %%
feb_df=pd.read_csv('SalesData/Sales_February_2019.csv')
feb_df
# Out:
#       Order ID                   Product Quantity Ordered Price Each  \
# 0       150502                    iPhone                1        700
# 1       150503     AA Batteries (4-pack)                1       3.84
# 2       150504    27in 4K Gaming Monitor                1     389.99
# 3       150505  Lightning Charging Cable                1      14.95
# 4       150506     AA Batteries (4-pack)                2       3.84
# ...        ...                       ...              ...        ...
# 12031   162004  Apple Airpods Headphones                1        150
# 12032   162005    AAA Batteries (4-pack)                2       2.99
# 12033   162006      USB-C Charging Cable                1      11.95
# 12034   162007      USB-C Charging Cable                1      11.95
# 12035   162008          27in FHD Monitor                1     149.99
#
#            Order Date                         Purchase Address
# 0      02/18/19 01:35        866 Spruce St, Portland, ME 04101
# ...

# %% [markdown]
# ## Concat Jan and Feb

# %%
df=pd.concat([jan_df,feb_df])
df
# Out:
#       Order ID                   Product Quantity Ordered Price Each  \
# 0       141234                    iPhone                1        700
# 1       141235  Lightning Charging Cable                1      14.95
# 2       141236          Wired Headphones                2      11.99
# 3       141237          27in FHD Monitor                1     149.99
# 4       141238          Wired Headphones                1      11.99
# ...        ...                       ...              ...        ...
# 12031   162004  Apple Airpods Headphones                1        150
# 12032   162005    AAA Batteries (4-pack)                2       2.99
# 12033   162006      USB-C Charging Cable                1      11.95
# 12034   162007      USB-C Charging Cable                1      11.95
# 12035   162008          27in FHD Monitor                1     149.99
#
#            Order Date                         Purchase Address
# 0      01/22/19 21:25          944 Walnut St, Boston, MA 02215
# ...

# %% [markdown]
# ## Smart Approach

# %%
filenames=os.listdir('SalesData')
filenames
# Out:
# ['Sales_April_2019.csv',
#  'Sales_August_2019.csv',
#  'Sales_December_2019.csv',
#  'Sales_February_2019.csv',
#  'Sales_January_2019.csv',
#  'Sales_July_2019.csv',
#  'Sales_June_2019.csv',
#  'Sales_March_2019.csv',
#  'Sales_May_2019.csv',
#  'Sales_November_2019.csv',
#  'Sales_October_2019.csv',
#  'Sales_September_2019.csv']

# %%
edf=pd.DataFrame()

for filename in filenames:
    df=pd.read_csv(f'SalesData/{filename}')
    edf=pd.concat([edf,df])
edf
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       176558        USB-C Charging Cable                2      11.95
# 1          NaN                         NaN              NaN        NaN
# 2       176559  Bose SoundSport Headphones                1      99.99
# 3       176560                Google Phone                1        600
# 4       176560            Wired Headphones                1      11.99
# ...        ...                         ...              ...        ...
# 11681   259353      AAA Batteries (4-pack)                3       2.99
# 11682   259354                      iPhone                1        700
# 11683   259355                      iPhone                1        700
# 11684   259356      34in Ultrawide Monitor                1     379.99
# 11685   259357        USB-C Charging Cable                1      11.95
#
#            Order Date                         Purchase Address
# ...

# %% [markdown]
# ## Convert to CSV File

# %%
edf.to_csv('Sales.csv',index=False)

# %% [markdown]
# ## Load Big File

# %%
df=pd.read_csv('Sales.csv')
df
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 1           NaN                         NaN              NaN        NaN
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1        700
# 186847   259355                      iPhone                1        700
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address
# ...

# %% [markdown]
# ## Drop all the Rows with Missing Columns

# %%
df=df.dropna(how='all')
df
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# 5        176561            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1        700
# 186847   259355                      iPhone                1        700
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address
# ...

# %% [markdown]
# ### Checking the reason for the Error for creating the new Amount column

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 186305 entries, 0 to 186849
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          186305 non-null  object
#  1   Product           186305 non-null  object
#  2   Quantity Ordered  186305 non-null  object
#  3   Price Each        186305 non-null  object
#  4   Order Date        186305 non-null  object
#  5   Purchase Address  186305 non-null  object
# dtypes: object(6)
# memory usage: 9.9+ MB

# %% [markdown]
# ## Checking for Numeric

# %%
df['check']=df['Quantity Ordered'].str.isnumeric()
df
# Out:
# C:\Users\AFZAL\AppData\Local\Temp\ipykernel_18884\2953084014.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['check']=df['Quantity Ordered'].str.isnumeric()
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# 5        176561            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# ...

# %%
ndf=df.loc[df['check']==False]
ndf
# Out:
#         Order ID  Product  Quantity Ordered  Price Each  Order Date  \
# 519     Order ID  Product  Quantity Ordered  Price Each  Order Date
# 1149    Order ID  Product  Quantity Ordered  Price Each  Order Date
# 1155    Order ID  Product  Quantity Ordered  Price Each  Order Date
# 2878    Order ID  Product  Quantity Ordered  Price Each  Order Date
# 2893    Order ID  Product  Quantity Ordered  Price Each  Order Date
# ...          ...      ...               ...         ...         ...
# 185164  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 185551  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 186563  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 186632  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 186738  Order ID  Product  Quantity Ordered  Price Each  Order Date
#
#         Purchase Address  check
# 519     Purchase Address  False
# 1149    Purchase Address  False
# 1155    Purchase Address  False
# ...

# %% [markdown]
# ## Picking out only True Values

# %%
df=df.loc[df['check']==True]
df
# Out:
#         Order ID                     Product  Quantity Ordered  Price Each  \
# 0         176558        USB-C Charging Cable                 2       11.95
# 1         176559  Bose SoundSport Headphones                 1       99.99
# 2         176560                Google Phone                 1      600.00
# 3         176560            Wired Headphones                 1       11.99
# 4         176561            Wired Headphones                 1       11.99
# ...          ...                         ...               ...         ...
# 185945    259353      AAA Batteries (4-pack)                 3        2.99
# 185946    259354                      iPhone                 1      700.00
# 185947    259355                      iPhone                 1      700.00
# 185948    259356      34in Ultrawide Monitor                 1      379.99
# 185949    259357        USB-C Charging Cable                 1       11.95
#
# ...

# %% [markdown]
# ## Resave the Data

# %%
df.to_csv('Sales.csv',index=False)

# %% [markdown]
# ## Reload the Data

# %%
df=pd.read_csv('Sales.csv')
df
# Out:
#         Order ID                     Product  Quantity Ordered  Price Each  \
# 0         176558        USB-C Charging Cable                 2       11.95
# 1         176559  Bose SoundSport Headphones                 1       99.99
# 2         176560                Google Phone                 1      600.00
# 3         176560            Wired Headphones                 1       11.99
# 4         176561            Wired Headphones                 1       11.99
# ...          ...                         ...               ...         ...
# 185945    259353      AAA Batteries (4-pack)                 3        2.99
# 185946    259354                      iPhone                 1      700.00
# 185947    259355                      iPhone                 1      700.00
# 185948    259356      34in Ultrawide Monitor                 1      379.99
# 185949    259357        USB-C Charging Cable                 1       11.95
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 185950 entries, 0 to 185949
# Data columns (total 8 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          185950 non-null  int64
#  1   Product           185950 non-null  object
#  2   Quantity Ordered  185950 non-null  int64
#  3   Price Each        185950 non-null  float64
#  4   Order Date        185950 non-null  object
#  5   Purchase Address  185950 non-null  object
#  6   check             185950 non-null  bool
#  7   Amount            185950 non-null  float64
# dtypes: bool(1), float64(2), int64(2), object(3)
# memory usage: 10.1+ MB

# %% [markdown]
# ## Again creating the New Column-->Amount

# %%
df['Amount']=df['Quantity Ordered'] * df['Price Each']
df
# Out:
#         Order ID                     Product  Quantity Ordered  Price Each  \
# 0         176558        USB-C Charging Cable                 2       11.95
# 1         176559  Bose SoundSport Headphones                 1       99.99
# 2         176560                Google Phone                 1      600.00
# 3         176560            Wired Headphones                 1       11.99
# 4         176561            Wired Headphones                 1       11.99
# ...          ...                         ...               ...         ...
# 185945    259353      AAA Batteries (4-pack)                 3        2.99
# 185946    259354                      iPhone                 1      700.00
# 185947    259355                      iPhone                 1      700.00
# 185948    259356      34in Ultrawide Monitor                 1      379.99
# 185949    259357        USB-C Charging Cable                 1       11.95
#
# ...

# %% [markdown]
# ## Month

# %%
df['Order Date']= pd.to_datetime(df['Order Date'])
df
# Out:
#         Order ID                     Product  Quantity Ordered  Price Each  \
# 0         176558        USB-C Charging Cable                 2       11.95
# 1         176559  Bose SoundSport Headphones                 1       99.99
# 2         176560                Google Phone                 1      600.00
# 3         176560            Wired Headphones                 1       11.99
# 4         176561            Wired Headphones                 1       11.99
# ...          ...                         ...               ...         ...
# 185945    259353      AAA Batteries (4-pack)                 3        2.99
# 185946    259354                      iPhone                 1      700.00
# 185947    259355                      iPhone                 1      700.00
# 185948    259356      34in Ultrawide Monitor                 1      379.99
# 185949    259357        USB-C Charging Cable                 1       11.95
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 185950 entries, 0 to 185949
# Data columns (total 8 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          185950 non-null  int64
#  1   Product           185950 non-null  object
#  2   Quantity Ordered  185950 non-null  int64
#  3   Price Each        185950 non-null  float64
#  4   Order Date        185950 non-null  datetime64[ns]
#  5   Purchase Address  185950 non-null  object
#  6   check             185950 non-null  bool
#  7   Amount            185950 non-null  float64
# dtypes: bool(1), datetime64[ns](1), float64(2), int64(2), object(2)
# memory usage: 10.1+ MB

# %%
df['Month']=df['Order Date'].dt.month
df['Month Name']=df['Order Date'].dt.month_name()
df['Hour']=df['Order Date'].dt.hour
df
# Out:
#         Order ID                     Product  Quantity Ordered  Price Each  \
# 0         176558        USB-C Charging Cable                 2       11.95
# 1         176559  Bose SoundSport Headphones                 1       99.99
# 2         176560                Google Phone                 1      600.00
# 3         176560            Wired Headphones                 1       11.99
# 4         176561            Wired Headphones                 1       11.99
# ...          ...                         ...               ...         ...
# 185945    259353      AAA Batteries (4-pack)                 3        2.99
# 185946    259354                      iPhone                 1      700.00
# 185947    259355                      iPhone                 1      700.00
# 185948    259356      34in Ultrawide Monitor                 1      379.99
# 185949    259357        USB-C Charging Cable                 1       11.95
#
# ...

# %% [markdown]
# ## To find City

# %%
st='917 1st St,Dallas, TX 75001'
st.split(',')[1].strip()
# Out:
# 'Dallas'

# %%
def find_city(st):
    return st.split(',')[1].strip()

# %%
df['City']=df['Purchase Address'].apply(find_city)
df
# Out:
#         Order ID                     Product  Quantity Ordered  Price Each  \
# 0         176558        USB-C Charging Cable                 2       11.95
# 1         176559  Bose SoundSport Headphones                 1       99.99
# 2         176560                Google Phone                 1      600.00
# 3         176560            Wired Headphones                 1       11.99
# 4         176561            Wired Headphones                 1       11.99
# ...          ...                         ...               ...         ...
# 185945    259353      AAA Batteries (4-pack)                 3        2.99
# 185946    259354                      iPhone                 1      700.00
# 185947    259355                      iPhone                 1      700.00
# 185948    259356      34in Ultrawide Monitor                 1      379.99
# 185949    259357        USB-C Charging Cable                 1       11.95
#
# ...

# %%
df.to_csv('Sales.csv',index=False)

# %%
df
# Out:
#         Order ID                     Product  Quantity Ordered  Price Each  \
# 0         176558        USB-C Charging Cable                 2       11.95
# 1         176559  Bose SoundSport Headphones                 1       99.99
# 2         176560                Google Phone                 1      600.00
# 3         176560            Wired Headphones                 1       11.99
# 4         176561            Wired Headphones                 1       11.99
# ...          ...                         ...               ...         ...
# 185945    259353      AAA Batteries (4-pack)                 3        2.99
# 185946    259354                      iPhone                 1      700.00
# 185947    259355                      iPhone                 1      700.00
# 185948    259356      34in Ultrawide Monitor                 1      379.99
# 185949    259357        USB-C Charging Cable                 1       11.95
#
# ...

# %% [markdown]
# ### What was the best month for sales? How much was earned that month?

# %%
ndf=df.groupby(['Month','Month Name']).agg(
    revenue=('Amount','sum')
)
ndf=ndf.reset_index()
ndf
# Out:
#     Month Month Name     revenue
# 0       1    January  1822256.73
# 1       2   February  2202022.42
# 2       3      March  2807100.38
# 3       4      April  3390670.24
# 4       5        May  3152606.75
# 5       6       June  2577802.26
# 6       7       July  2647775.76
# 7       8     August  2244467.88
# 8       9  September  2097560.13
# 9      10    October  3736726.88
# 10     11   November  3199603.20
# 11     12   December  4613443.34

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 185950 entries, 0 to 185949
# Data columns (total 12 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          185950 non-null  int64
#  1   Product           185950 non-null  object
#  2   Quantity Ordered  185950 non-null  int64
#  3   Price Each        185950 non-null  float64
#  4   Order Date        185950 non-null  datetime64[ns]
#  5   Purchase Address  185950 non-null  object
#  6   check             185950 non-null  bool
#  7   Amount            185950 non-null  float64
#  8   Month             185950 non-null  int32
#  9   Month Name        185950 non-null  object
#  10  Hour              185950 non-null  int32
#  11  City              185950 non-null  object
# dtypes: bool(1), datetime64[ns](1), float64(2), int32(2), int64(2), object(4)
# memory usage: 14.4+ MB

# %%
ndf.to_csv('Monthly Sales.csv',index=False)

# %% [markdown]
# ## Line Chart

# %%
plt.figure(figsize=(10,5))
plt.plot(ndf['Month Name'],ndf['revenue'],marker='o',label='Retail Sales',color='red')
plt.title('retail Sales')
plt.grid()
plt.legend()
plt.xlabel('Month')
plt.ylabel('Sales')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Bar Chart

# %%
plt.figure(figsize=(10,5))
plt.bar(ndf['Month Name'],ndf['revenue'],label='Retail Sales',color='yellow')
plt.title('Retail Sales')
plt.grid()
plt.legend()
plt.xlabel('Month')
plt.ylabel('Sales')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Bar Line Chart

# %%
plt.figure(figsize=(10,5))
plt.plot(ndf['Month Name'],ndf['revenue'],marker='o',label='Retail Sales',color='red')
plt.bar(ndf['Month Name'],ndf['revenue'],label='Retail Sales',color='yellow')
plt.title('Retail Sales')
plt.grid()
plt.legend()
plt.xlabel('Month')
plt.ylabel('Sales')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Total Average Sales

# %%
ndf=df.groupby(['Month','Month Name']).agg(
    revenue=('Amount','sum'),
    avg_sale=('Amount','mean')
)
ndf=ndf.reset_index()
ndf.to_csv('Monthly Sales.csv',index=False)

# %% [markdown]
# ## Bar Line Chart with Average Sales

# %%
plt.figure(figsize=(10,5))
plt.plot(ndf['Month Name'],ndf['avg_sale'],marker='o',label='Retail Sales',color='red')
plt.bar(ndf['Month Name'],ndf['revenue'],label='Retail Sales',color='yellow')
plt.title('Retail Sales')
plt.grid()
plt.legend()
plt.xlabel('Month')
plt.ylabel('Sales')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Dividing for Perfect Bar Line graph

# %%
ndf['revenue']=ndf['revenue']/10000
ndf
# Out:
#     Month Month Name     revenue    avg_sale
# 0       1    January  182.225673  187.687376
# 1       2   February  220.202242  183.884962
# 2       3      March  280.710038  185.250471
# 3       4      April  339.067024  185.495390
# 4       5        May  315.260675  190.305852
# 5       6       June  257.780226  190.187565
# 6       7       July  264.777576  185.249826
# 7       8     August  224.446788  187.648849
# 8       9  September  209.756013  180.497387
# 9      10    October  373.672688  184.238580
# 10     11   November  319.960320  182.074956
# 11     12   December  461.344334  184.655913

# %%
plt.figure(figsize=(10,5))
plt.plot(ndf['Month Name'],ndf['avg_sale'],marker='o',label='Average Retail Sales(Actual Sales)',color='red')
plt.bar(ndf['Month Name'],ndf['revenue'],label='Total Retail Sales(10000s)',color='yellow')
plt.title('Retail Sales')
plt.grid()
plt.legend()
plt.xlabel('Month')
plt.ylabel('Sales')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Pie Chart

# %%
plt.figure(figsize=(5,5),facecolor='pink')
plt.pie(ndf['revenue'],labels=ndf['Month Name'],autopct='%.2f%%')

plt.show()

# %% [markdown]
# ## Line Chart

# %%
sns.relplot(data=ndf,x='Month Name',y='revenue',kind='line',aspect=2)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Finding Quarter Sales (By Default-USA)

# %%
df['Quarter_USA']=df['Order Date'].dt.quarter
df
# Out:
#         Order ID                     Product  Quantity Ordered  Price Each  \
# 0         176558        USB-C Charging Cable                 2       11.95
# 1         176559  Bose SoundSport Headphones                 1       99.99
# 2         176560                Google Phone                 1      600.00
# 3         176560            Wired Headphones                 1       11.99
# 4         176561            Wired Headphones                 1       11.99
# ...          ...                         ...               ...         ...
# 185945    259353      AAA Batteries (4-pack)                 3        2.99
# 185946    259354                      iPhone                 1      700.00
# 185947    259355                      iPhone                 1      700.00
# 185948    259356      34in Ultrawide Monitor                 1      379.99
# 185949    259357        USB-C Charging Cable                 1       11.95
#
# ...

# %% [markdown]
# ### Creating a Function For Indian Quarter

# %%
def q(Quarter):
    if(Quarter==2):
        return 1
    elif(Quarter==3):
        return 2
    elif(Quarter==4):
        return 3
    else:
        return 4

# %%
df['Quarter']=df['Quarter_USA'].apply(q)
df
# Out:
#         Order ID                     Product  Quantity Ordered  Price Each  \
# 0         176558        USB-C Charging Cable                 2       11.95
# 1         176559  Bose SoundSport Headphones                 1       99.99
# 2         176560                Google Phone                 1      600.00
# 3         176560            Wired Headphones                 1       11.99
# 4         176561            Wired Headphones                 1       11.99
# ...          ...                         ...               ...         ...
# 185945    259353      AAA Batteries (4-pack)                 3        2.99
# 185946    259354                      iPhone                 1      700.00
# 185947    259355                      iPhone                 1      700.00
# 185948    259356      34in Ultrawide Monitor                 1      379.99
# 185949    259357        USB-C Charging Cable                 1       11.95
#
# ...

# %% [markdown]
# ## Now Removing the USA Quarter

# %%
df=df.drop(columns='Quarter_USA')
df
# Out:
#         Order ID                     Product  Quantity Ordered  Price Each  \
# 0         176558        USB-C Charging Cable                 2       11.95
# 1         176559  Bose SoundSport Headphones                 1       99.99
# 2         176560                Google Phone                 1      600.00
# 3         176560            Wired Headphones                 1       11.99
# 4         176561            Wired Headphones                 1       11.99
# ...          ...                         ...               ...         ...
# 185945    259353      AAA Batteries (4-pack)                 3        2.99
# 185946    259354                      iPhone                 1      700.00
# 185947    259355                      iPhone                 1      700.00
# 185948    259356      34in Ultrawide Monitor                 1      379.99
# 185949    259357        USB-C Charging Cable                 1       11.95
#
# ...

# %% [markdown]
# ## Sales According to Quarter

# %%
ndf=df.groupby('Quarter').agg(
    Revenue=('Amount','sum'),
    Avg_Sale=('Amount','sum'),
    Quantity=('Quantity Ordered','sum')

)
ndf=ndf.reset_index()
ndf
# Out:
#    Quarter      Revenue     Avg_Sale  Quantity
# 0        1   9121079.25   9121079.25     54478
# 1        2   6989803.77   6989803.77     42629
# 2        3  11549773.42  11549773.42     70615
# 3        4   6831379.53   6831379.53     41357

# %% [markdown]
# ## Line Chart

# %%
plt.figure(figsize=(10,5))
ndf['Quarter']=ndf['Quarter'].astype(str)
plt.plot(ndf['Quarter'],ndf['Revenue'],marker='o',label='Retail Sales',color='green')
plt.title('Retail Sales')
plt.grid()
plt.legend()
plt.xlabel('Quarter')
plt.ylabel('Sales')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Bar Chart

# %%
plt.figure(figsize=(10,5))
plt.bar(ndf['Quarter'],ndf['Revenue'],label='Retail Sales',color='blue',width=0.3)
plt.title('Retail Sales')
plt.grid()
plt.legend()
plt.xlabel('Quarter')
plt.ylabel('Sales')
plt.xticks(rotation=30,fontsize=10)
plt.show()

# %% [markdown]
# ## Bar Line Chart

# %%
plt.figure(figsize=(10,5))
plt.plot(ndf['Quarter'],ndf['Revenue'],marker='s',label='Retail Sales',color='red')
plt.bar(ndf['Quarter'],ndf['Revenue'],label='Retail Sales',color='yellow',width=0.4)
plt.title('Retail Sales')
plt.grid()
plt.legend()
plt.xlabel('Quarter')
plt.ylabel('Sales')
plt.xticks(rotation=20)
plt.show()

# %% [markdown]
# ## Pie Chart

# %%
plt.figure(figsize=(5,5),facecolor='pink')
plt.pie(ndf['Revenue'],labels=ndf['Quarter'],autopct='%.2f%%')
plt.show()

# %% [markdown]
# ## Monthly Product Purchased by Costumer

# %%
df
# Out:
#         Order ID                     Product  Quantity Ordered  Price Each  \
# 0         176558        USB-C Charging Cable                 2       11.95
# 1         176559  Bose SoundSport Headphones                 1       99.99
# 2         176560                Google Phone                 1      600.00
# 3         176560            Wired Headphones                 1       11.99
# 4         176561            Wired Headphones                 1       11.99
# ...          ...                         ...               ...         ...
# 185945    259353      AAA Batteries (4-pack)                 3        2.99
# 185946    259354                      iPhone                 1      700.00
# 185947    259355                      iPhone                 1      700.00
# 185948    259356      34in Ultrawide Monitor                 1      379.99
# 185949    259357        USB-C Charging Cable                 1       11.95
#
# ...

# %%
ndf=df.drop_duplicates(subset='Purchase Address')
ndf
# Out:
#         Order ID                     Product  Quantity Ordered  Price Each  \
# 0         176558        USB-C Charging Cable                 2       11.95
# 1         176559  Bose SoundSport Headphones                 1       99.99
# 2         176560                Google Phone                 1      600.00
# 4         176561            Wired Headphones                 1       11.99
# 5         176562        USB-C Charging Cable                 1       11.95
# ...          ...                         ...               ...         ...
# 185939    259348    Lightning Charging Cable                 1       14.95
# 185940    259349      AAA Batteries (4-pack)                 1        2.99
# 185943    259351    Apple Airpods Headphones                 1      150.00
# 185945    259353      AAA Batteries (4-pack)                 3        2.99
# 185947    259355                      iPhone                 1      700.00
#
# ...

# %%
ndf=ndf['Month Name'].value_counts()
ndf=ndf.reset_index()
ndf
# Out:
#    Month Name  count
# 0    December  21369
# 1       April  17106
# 2     October  12603
# 3    November  11540
# 4         May  11287
# 5        July  10881
# 6       March  10845
# 7      August  10737
# 8        June   9982
# 9    February   9773
# 10    January   7664
# 11  September   7000

# %% [markdown]
# ## Line Chart

# %%
plt.figure(figsize=(10,5))
plt.plot(ndf['Month Name'],ndf['count'],marker='o',label='Product Purchased',color='green')
plt.title('Product Purchased')
plt.grid()
plt.legend()
plt.xlabel('Month Name')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Bar Chart

# %%
plt.figure(figsize=(10,5))
plt.bar(ndf['Month Name'],ndf['count'],label='Product Purchased',color='cyan',width=0.3)
plt.title('Product Purchased')
plt.grid()
plt.legend()
plt.xlabel('Month Name')
plt.ylabel('Count')
plt.xticks(rotation=30,fontsize=10)
plt.show()

# %% [markdown]
# ## Bar Line Chart

# %%
plt.figure(figsize=(10,5))
plt.plot(ndf['Month Name'],ndf['count'],marker='s',label='Product Purchased',color='brown')
plt.bar(ndf['Month Name'],ndf['count'],label='Product Purchased',color='pink',width=0.4)
plt.title('Product Purchased')
plt.grid()
plt.legend()
plt.xlabel('Month Name')
plt.ylabel('Count')
plt.xticks(rotation=20)
plt.show()

# %% [markdown]
# ## Pie Chart

# %%
plt.figure(figsize=(5,5),facecolor='pink')
plt.pie(ndf['count'],labels=ndf['Month Name'],autopct='%.2f%%')
plt.show()
